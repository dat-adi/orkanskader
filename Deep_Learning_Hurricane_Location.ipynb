# %% [markdown]
# # Data Loading and Processing
# The goal of this deep learning section is to predict the location(being latitude and longitude) of the hurricane in the next timestamp given the information we use to predict radius of wind speed.

# %%
import pandas as pd
import numpy as np
import os
# from google.colab import drive
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd(),os.listdir()
# drive.mount('/content/drive')
file_path1 = '/cis/home/ywen15/Documents/Tornados/ibtracs.since1980.list.v04r01.csv'  #the north atlantic data from https://zenodo.org/records/12740372
df1 = pd.read_csv(file_path1)

df1 = df1.iloc[:, 1:]

df = df1.copy()

df
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (1,2,8,9,14,19,20,172,173) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        SEASON NUMBER BASIN SUBBASIN     NAME             ISO_TIME NATURE  \
# 0        Year
# 1        1980      1    SP       MM     PENI  1980-01-01 00:00:00     TS
# 2        1980      1    SP       MM     PENI  1980-01-01 03:00:00     TS
# 3        1980      1    SP       MM     PENI  1980-01-01 06:00:00     TS
# 4        1980      1    SP       MM     PENI  1980-01-01 09:00:00     TS
# ...       ...    ...   ...      ...      ...                  ...    ...
# 297547   2024     81    WP       MM  YINXING  2024-11-04 12:00:00     NR
# 297548   2024     81    WP       MM  YINXING  2024-11-04 15:00:00     NR
# 297549   2024     81    WP       MM  YINXING  2024-11-04 18:00:00     NR
# 297550   2024     81    WP       MM  YINXING  2024-11-04 21:00:00     NR
# 297551   2024     81    WP       MM  YINXING  2024-11-05 00:00:00     NR
#
#                   LAT           LON WMO_WIND  ... BOM_GUST_PER REUNION_GUST  \
# 0       degrees_north  degrees_east      kts  ...       second          kts
# 1               -12.5         172.5           ...
# 2               -12.2         172.4           ...
# 3               -11.9         172.4           ...
# 4               -11.7         172.4           ...
# ...               ...           ...      ...  ...          ...          ...
# 297547           14.3         130.1           ...
# 297548           14.7         129.6           ...
# 297549           15.1         129.0           ...
# 297550           15.6         128.3           ...
# 297551           16.2         127.5           ...
#
#        REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE USA_SEARAD_SE USA_SEARAD_SW  \
# 0                second         ft         nmile         nmile         nmile
# 1
# 2
# 3
# 4
# ...                 ...        ...           ...           ...           ...
# 297547
# 297548
# 297549
# 297550
# 297551
#
#        USA_SEARAD_NW STORM_SPEED STORM_DIR
# 0              nmile         kts   degrees
# 1                              6       350
# 2                              6       350
# 3                              5       360
# 4                              4        10
# ...              ...         ...       ...
# 297547                        15       310
# 297548                        13       305
# 297549                        15       305
# 297550                        18       305
# 297551                        19       310
#
# [297552 rows x 173 columns]

# %% [markdown]
# Set radius to zero when it is reasonable to do so. Aside from that, remove the lines with missing data.

# %%
#keep what we will use for learning(and the output R)

df2 = df[['NAME','ISO_TIME','LAT','LON', 'USA_WIND','USA_R34_NE', 'USA_R50_NE', 'USA_R64_NE','USA_RMW']].copy()
df2 = df2.iloc[1:]#remove the first row

df2.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df2.reset_index(drop=True, inplace=True)

#make the items numerical values for computation
df2[['USA_R34_NE']] = df2[['USA_R34_NE']].apply(pd.to_numeric, errors='coerce')
df2[['USA_RMW', 'USA_R64_NE','USA_R50_NE']] = df2[['USA_RMW', 'USA_R64_NE','USA_R50_NE']].apply(pd.to_numeric, errors='coerce')
df2[['USA_WIND']] = df2[['USA_WIND']].apply(pd.to_numeric, errors='coerce')
df2[['LAT']] = df2[['LAT']].apply(pd.to_numeric, errors='coerce')

#remove missing data, if the max wind speed is less than x, set the radius of area with this wind speed to be 0
df2 = df2.dropna(subset=['USA_WIND'])
df2.loc[df2['USA_WIND']<64,'USA_R64_NE']=0
df2.loc[df2['USA_WIND']<50,'USA_R50_NE']=0
df2.loc[df2['USA_WIND']<34,'USA_R34_NE']=0

numeric_columns = ['LAT', 'USA_R34_NE', 'USA_RMW', 'USA_WIND']
df2.dropna(subset=numeric_columns, inplace=True)
df2.dropna(inplace=True)
df2
# Out:
#            NAME             ISO_TIME   LAT    LON  USA_WIND  USA_R34_NE  \
# 151265   ADOLPH  2001-05-27 00:00:00  13.5 -100.2      40.0       120.0
# 151266   ADOLPH  2001-05-27 03:00:00  13.4 -100.1      45.0       120.0
# 151307   ADOLPH  2001-06-01 06:00:00  16.2 -112.0      45.0        50.0
# 151308   ADOLPH  2001-06-01 09:00:00  16.2 -112.1      40.0        40.0
# 151309   ADOLPH  2001-06-01 12:00:00  16.3 -112.3      35.0        30.0
# ...         ...                  ...   ...    ...       ...         ...
# 297533   RAFAEL  2024-11-04 18:00:00  15.1  -76.4      40.0        70.0
# 297534   RAFAEL  2024-11-04 21:00:00  15.4  -76.6      40.0        80.0
# 297535   RAFAEL  2024-11-05 00:00:00  15.8  -76.9      40.0        90.0
# 297536  YINXING  2024-11-03 06:00:00   9.7  138.2      29.0         0.0
# 297537  YINXING  2024-11-03 09:00:00  10.3  137.5      32.0         0.0
#
#         USA_R50_NE  USA_R64_NE  USA_RMW
# 151265         0.0         0.0     40.0
# 151266         0.0         0.0     40.0
# 151307         0.0         0.0     20.0
# 151308         0.0         0.0     35.0
# 151309         0.0         0.0     50.0
# ...            ...         ...      ...
# 297533         0.0         0.0     70.0
# 297534         0.0         0.0     55.0
# 297535         0.0         0.0     40.0
# 297536         0.0         0.0     65.0
# 297537         0.0         0.0     54.0
#
# [90337 rows x 9 columns]

# %%
#split data by hurriance, making each hurricane its own dataset
datasets = [group for _, group in df2.groupby('NAME')]

# %%
#split datasets into train (80%), validation (10%), and test (10%)
train_datasets, temp_datasets = train_test_split(datasets, test_size=0.2, random_state=42)
val_datasets, test_datasets = train_test_split(temp_datasets, test_size=0.5, random_state=42)

print(f"Number of training datasets: {len(train_datasets)}")
print(f"Number of validation datasets: {len(val_datasets)}")
print(f"Number of testing datasets: {len(test_datasets)}")
# Out:
# Number of training datasets: 785
# Number of validation datasets: 98
# Number of testing datasets: 99

# %% [markdown]
# #Training
# Train the LSTM models(one for latitude and one for longitude) using each hurricane in the training set separately,then validate and test using the remaining hurricanes.

# %%
class LSTMModel(nn.Module):#use LSTM model because it remembers the entire path instead of only using the previous information
  def __init__(self, input_dim, hidden_dim, output_dim):
    super(LSTMModel, self).__init__()
    self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
    self.fc = nn.Linear(hidden_dim, output_dim)

  def forward(self, x):
    lstm_out, _ = self.lstm(x)
    lstm_out = lstm_out[:, -1, :]
    pred = self.fc(lstm_out)
    return pred

# %%
#preparing the data, essentially transform all data to numerical values, then preparing them in the list returned.
def prepare_data_for_training(dataset, sequence_length=5):
  features = ['LAT', 'LON', 'USA_WIND', 'USA_R34_NE', 'USA_R50_NE', 'USA_R64_NE', 'USA_RMW']
  target_lat = 'LAT'
  target_lon = 'LON'

  #sort data by time as we care about the hurricane movement by time
  dataset = dataset.sort_values(by='ISO_TIME')

  #convert all feature columns to numeric
  dataset[features] = dataset[features].apply(pd.to_numeric, errors='coerce')
  dataset[target_lat] = pd.to_numeric(dataset[target_lat], errors='coerce')
  dataset[target_lon] = pd.to_numeric(dataset[target_lon], errors='coerce')

  #drop columns without target lattidude and longitude, being the last row(as we cannot find its true next position)
  dataset.dropna(subset=features + [target_lat, target_lon], inplace=True)

  X, y_lat, y_lon = [], [], []
  data_values = dataset[features].values
  lat_values = dataset[target_lat].values
  lon_values = dataset[target_lon].values

  for i in range(sequence_length, len(dataset)):
    X.append(data_values[:i].astype(np.float32))
    y_lat.append(lat_values[i])
    y_lon.append(lon_values[i])

  return X, y_lat, y_lon

# %%
#parameters used for training
input_dim = len(['LAT', 'LON', 'USA_WIND', 'USA_R34_NE', 'USA_R50_NE', 'USA_R64_NE', 'USA_RMW'])
hidden_dim = 64
output_dim = 1
learning_rate = 0.001
num_epochs = 10
sequence_length = 5

# %%
#initalize lattitude and longitude model
model_lat = LSTMModel(input_dim, hidden_dim, output_dim)#LAT
model_lon = LSTMModel(input_dim, hidden_dim, output_dim)#LON

model_lat.load_state_dict(torch.load("/cis/home/ywen15/Documents/Tornados/model_lat.pth", weights_only=True))
model_lon.load_state_dict(torch.load("/cis/home/ywen15/Documents/Tornados/model_lon.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1628000/3957423419.py in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
#initalize lattitude and longitude model
model_lat = LSTMModel(input_dim, hidden_dim, output_dim)#LAT
model_lon = LSTMModel(input_dim, hidden_dim, output_dim)#LON

#loss function
criterion = nn.MSELoss()
optimizer_lat = torch.optim.Adam(model_lat.parameters(), lr=learning_rate)
optimizer_lon = torch.optim.Adam(model_lon.parameters(), lr=learning_rate)

#train separately for each hurricane
for dataset_idx, dataset in enumerate(train_datasets):
    print(f"Training on dataset {dataset_idx + 1}/{len(train_datasets)}")

    #get data for current dataset
    X_train, y_lat_train, y_lon_train = prepare_data_for_training(dataset, sequence_length=5)

    #skip if there isnt enough data
    if len(X_train) == 0:
        print(f"Skipping dataset {dataset_idx + 1} due to insufficient data.")
        continue

    #convert to tensors
    X_train_tensor = [torch.tensor(x, dtype=torch.float32) for x in X_train]
    y_lat_train_tensor = torch.tensor(y_lat_train, dtype=torch.float32).unsqueeze(1)
    y_lon_train_tensor = torch.tensor(y_lon_train, dtype=torch.float32).unsqueeze(1)

    #train in this dataset
    for epoch in range(num_epochs):
        total_loss_lat = 0.0
        total_loss_lon = 0.0
        model_lat.train()
        model_lon.train()

        for i in range(len(X_train_tensor)):
            #train lattitude
            optimizer_lat.zero_grad()
            input_seq = X_train_tensor[i].unsqueeze(0)
            lat_pred = model_lat(input_seq)
            loss_lat = criterion(lat_pred, y_lat_train_tensor[i].unsqueeze(0))
            loss_lat.backward()
            optimizer_lat.step()
            total_loss_lat += loss_lat.item()

            #train longitude
            optimizer_lon.zero_grad()
            lon_pred = model_lon(input_seq)
            loss_lon = criterion(lon_pred, y_lon_train_tensor[i].unsqueeze(0))
            loss_lon.backward()
            optimizer_lon.step()
            total_loss_lon += loss_lon.item()

        print(f"Epoch {epoch + 1}/{num_epochs}, Latitude Loss: {total_loss_lat / len(X_train_tensor):.4f}, Longitude Loss: {total_loss_lon / len(X_train_tensor):.4f}")
# Out:
# Training on dataset 1/785
# Epoch 1/10, Latitude Loss: 183.4537, Longitude Loss: 14114.6374
# Epoch 2/10, Latitude Loss: 46.6235, Longitude Loss: 11845.5831
# Epoch 3/10, Latitude Loss: 18.5889, Longitude Loss: 9799.7897
# Epoch 4/10, Latitude Loss: 14.4319, Longitude Loss: 8132.5962
# Epoch 5/10, Latitude Loss: 13.4598, Longitude Loss: 6682.4107
# Epoch 6/10, Latitude Loss: 12.6862, Longitude Loss: 5424.6975
# Epoch 7/10, Latitude Loss: 11.7318, Longitude Loss: 4382.1642
# Epoch 8/10, Latitude Loss: 11.4279, Longitude Loss: 3505.5179
# Epoch 9/10, Latitude Loss: 11.3664, Longitude Loss: 2772.0169
# Epoch 10/10, Latitude Loss: 11.1882, Longitude Loss: 2163.7204
# Training on dataset 2/785
# Epoch 1/10, Latitude Loss: 33.2347, Longitude Loss: 1816.6676
# Epoch 2/10, Latitude Loss: 26.4434, Longitude Loss: 1500.7007
# Epoch 3/10, Latitude Loss: 25.7640, Longitude Loss: 1229.0636
# Epoch 4/10, Latitude Loss: 25.5260, Longitude Loss: 997.7409
# Epoch 5/10, Latitude Loss: 25.4594, Longitude Loss: 802.4341
# Epoch 6/10, Latitude Loss: 25.1323, Longitude Loss: 639.0993
# Epoch 7/10, Latitude Loss: 24.9744, Longitude Loss: 503.9312
# Epoch 8/10, Latitude Loss: 25.1294, Longitude Loss: 393.3574
# Epoch 9/10, Latitude Loss: 24.6917, Longitude Loss: 304.0407
# Epoch 10/10, Latitude Loss: 24.8559, Longitude Loss: 232.8838
# Training on dataset 3/785
# Epoch 1/10, Latitude Loss: 1552.0042, Longitude Loss: 1046.3853
# Epoch 2/10, Latitude Loss: 1421.2495, Longitude Loss: 1020.9875
# Epoch 3/10, Latitude Loss: 1203.9844, Longitude Loss: 1017.7199
# Epoch 4/10, Latitude Loss: 987.8550, Longitude Loss: 1014.2835
# Epoch 5/10, Latitude Loss: 880.6895, Longitude Loss: 1010.3050
# Epoch 6/10, Latitude Loss: 799.3420, Longitude Loss: 1005.9074
# Epoch 7/10, Latitude Loss: 702.1740, Longitude Loss: 1001.4097
# Epoch 5/10, Latitude Loss: 4.8665, Longitude Loss: 26.1338
# Epoch 6/10, Latitude Loss: 3.1565, Longitude Loss: 24.5199
# Epoch 7/10, Latitude Loss: 2.9341, Longitude Loss: 22.9857
# Epoch 8/10, Latitude Loss: 1.9155, Longitude Loss: 21.5548
# Epoch 9/10, Latitude Loss: 3.4791, Longitude Loss: 19.0564
# Epoch 10/10, Latitude Loss: 2.0386, Longitude Loss: 19.2021
# Training on dataset 784/785
# Epoch 1/10, Latitude Loss: 14.6071, Longitude Loss: 264.9414
# Epoch 2/10, Latitude Loss: 3.3919, Longitude Loss: 174.5683
# Epoch 3/10, Latitude Loss: 4.0980, Longitude Loss: 102.9253
# Epoch 4/10, Latitude Loss: 3.6152, Longitude Loss: 82.8650
# Epoch 5/10, Latitude Loss: 2.5995, Longitude Loss: 74.5381
# Epoch 6/10, Latitude Loss: 2.1035, Longitude Loss: 73.6984
# Epoch 7/10, Latitude Loss: 2.0695, Longitude Loss: 66.3275
# Epoch 8/10, Latitude Loss: 2.0926, Longitude Loss: 64.6465
# Epoch 9/10, Latitude Loss: 2.0622, Longitude Loss: 57.5359
# Epoch 10/10, Latitude Loss: 2.0836, Longitude Loss: 63.9784
# Training on dataset 785/785
# Epoch 1/10, Latitude Loss: 12.2155, Longitude Loss: 189.1786
# Epoch 2/10, Latitude Loss: 13.2828, Longitude Loss: 122.6501
# Epoch 3/10, Latitude Loss: 9.3518, Longitude Loss: 96.4216
# Epoch 4/10, Latitude Loss: 9.2552, Longitude Loss: 101.7562
# Epoch 5/10, Latitude Loss: 7.9450, Longitude Loss: 82.1469
# Epoch 6/10, Latitude Loss: 7.7834, Longitude Loss: 89.9281
# Epoch 7/10, Latitude Loss: 7.2864, Longitude Loss: 85.8591
# Epoch 8/10, Latitude Loss: 6.6653, Longitude Loss: 79.2448
# Epoch 9/10, Latitude Loss: 6.9495, Longitude Loss: 74.2991
# Epoch 10/10, Latitude Loss: 7.1144, Longitude Loss: 75.1245

# %%
#validation and print out validation result

expected_lon_list = []
expected_lat_list = []
predicted_lat_list = []
predicted_lon_list = []

for dataset_idx, dataset in enumerate(val_datasets):
    print(f"Validating on dataset {dataset_idx + 1}/{len(val_datasets)}")

    #prepare data for the current dataset
    X_val, y_lat_val, y_lon_val = prepare_data_for_training(dataset, sequence_length=5)

    #convert to tensors
    X_val_tensor = [torch.tensor(x, dtype=torch.float32) for x in X_val]
    y_lat_val_tensor = torch.tensor(y_lat_val, dtype=torch.float32).unsqueeze(1)
    y_lon_val_tensor = torch.tensor(y_lon_val, dtype=torch.float32).unsqueeze(1)

    #ensure models are in evaluation mode
    model_lat.eval()
    model_lon.eval()

    #compute predictions
    with torch.no_grad():
        for i in range(len(X_val_tensor)):
            input_seq = X_val_tensor[i].unsqueeze(0)

            #predict
            lat_pred = model_lat(input_seq)
            predicted_lat = lat_pred.item()
            lon_pred = model_lon(input_seq)
            predicted_lon = lon_pred.item()

            #store expected and predicted values
            expected_lon_list.append(y_lon_val_tensor[i].item())
            expected_lat_list.append(y_lat_val_tensor[i].item())
            predicted_lat_list.append(predicted_lat)
            predicted_lon_list.append(predicted_lon)

#plot expected latitutde/longitude vs actual latitude/longitude
plt.figure(figsize=(10, 5))
plt.scatter(expected_lat_list, predicted_lat_list, c='blue', label='Predicted LAT')
plt.title("Expected Longitude vs Predicted Latitude")
plt.xlabel("Expected Longitude")
plt.ylabel("Predicted Latitude")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(expected_lon_list, predicted_lon_list, c='red', label='Predicted LON')
plt.title("Expected Longitude vs Predicted Longitude")
plt.xlabel("Expected Longitude")
plt.ylabel("Predicted Longitude")
plt.legend()
plt.grid()
plt.show()
# Out:
# Validating on dataset 1/98
# Validating on dataset 2/98
# Validating on dataset 3/98
# Validating on dataset 4/98
# Validating on dataset 5/98
# Validating on dataset 6/98
# Validating on dataset 7/98
# Validating on dataset 8/98
# Validating on dataset 9/98
# Validating on dataset 10/98
# Validating on dataset 11/98
# Validating on dataset 12/98
# Validating on dataset 13/98
# Validating on dataset 14/98
# Validating on dataset 15/98
# Validating on dataset 16/98
# Validating on dataset 17/98
# Validating on dataset 18/98
# Validating on dataset 19/98
# Validating on dataset 20/98
# Validating on dataset 21/98
# Validating on dataset 22/98
# Validating on dataset 23/98
# Validating on dataset 24/98
# Validating on dataset 25/98
# Validating on dataset 26/98
# Validating on dataset 27/98
# Validating on dataset 28/98
# Validating on dataset 29/98
# Validating on dataset 30/98
# Validating on dataset 31/98
# Validating on dataset 32/98
# Validating on dataset 33/98
# Validating on dataset 34/98
# Validating on dataset 35/98
# Validating on dataset 36/98
# Validating on dataset 37/98
# Validating on dataset 38/98
# Validating on dataset 39/98
# Validating on dataset 40/98
# Validating on dataset 41/98
# Validating on dataset 42/98
# Validating on dataset 43/98
# Validating on dataset 44/98
# Validating on dataset 45/98
# Validating on dataset 46/98
# Validating on dataset 47/98
# Validating on dataset 48/98
# Validating on dataset 49/98
# Validating on dataset 50/98
# Validating on dataset 51/98
# Validating on dataset 52/98
# Validating on dataset 53/98
# Validating on dataset 54/98
# Validating on dataset 55/98
# Validating on dataset 56/98
# Validating on dataset 57/98
# Validating on dataset 58/98
# Validating on dataset 59/98
# Validating on dataset 60/98
# Validating on dataset 61/98
# Validating on dataset 62/98
# Validating on dataset 63/98
# Validating on dataset 64/98
# Validating on dataset 65/98
# Validating on dataset 66/98
# Validating on dataset 67/98
# Validating on dataset 68/98
# Validating on dataset 69/98
# Validating on dataset 70/98
# Validating on dataset 71/98
# Validating on dataset 72/98
# Validating on dataset 73/98
# Validating on dataset 74/98
# Validating on dataset 75/98
# Validating on dataset 76/98
# Validating on dataset 77/98
# Validating on dataset 78/98
# Validating on dataset 79/98
# Validating on dataset 80/98
# Validating on dataset 81/98
# Validating on dataset 82/98
# Validating on dataset 83/98
# Validating on dataset 84/98
# Validating on dataset 85/98
# Validating on dataset 86/98
# Validating on dataset 87/98
# Validating on dataset 88/98
# Validating on dataset 89/98
# Validating on dataset 90/98
# Validating on dataset 91/98
# Validating on dataset 92/98
# Validating on dataset 93/98
# Validating on dataset 94/98
# Validating on dataset 95/98
# Validating on dataset 96/98
# Validating on dataset 97/98
# Validating on dataset 98/98

# %%
#testing and print out testing result

expected_lon_list = []
expected_lat_list = []
predicted_lat_list = []
predicted_lon_list = []

for dataset_idx, dataset in enumerate(test_datasets):
    print(f"Testing on dataset {dataset_idx + 1}/{len(test_datasets)}")

    #prepare data for the current dataset
    X_test, y_lat_test, y_lon_test = prepare_data_for_training(dataset, sequence_length=5)

    #convert to tensors
    X_test_tensor = [torch.tensor(x, dtype=torch.float32) for x in X_test]
    y_lat_test_tensor = torch.tensor(y_lat_test, dtype=torch.float32).unsqueeze(1)
    y_lon_test_tensor = torch.tensor(y_lon_test, dtype=torch.float32).unsqueeze(1)

    #ensure models are in evaluation mode
    model_lat.eval()
    model_lon.eval()

    #compute predictions
    with torch.no_grad():
        for i in range(len(X_test_tensor)):
            input_seq = X_test_tensor[i].unsqueeze(0)

            #predict
            lat_pred = model_lat(input_seq)
            predicted_lat = lat_pred.item()
            lon_pred = model_lon(input_seq)
            predicted_lon = lon_pred.item()

            #store expected and predicted values
            expected_lon_list.append(y_lon_test_tensor[i].item())
            expected_lat_list.append(y_lat_test_tensor[i].item())
            predicted_lat_list.append(predicted_lat)
            predicted_lon_list.append(predicted_lon)

#plot expected latitutde/longitude vs actual latitude/longitude
plt.figure(figsize=(10, 5))
plt.scatter(expected_lat_list, predicted_lat_list, c='blue', label='Predicted LAT')
plt.plot([min(expected_lat_list), max(expected_lat_list)], [min(expected_lat_list), max(expected_lat_list)], color='red', linestyle='--', linewidth=2, label='Ideal Fit')
plt.title("Expected Latitude vs Predicted Latitude")
plt.xlabel("Expected Latitude")
plt.ylabel("Predicted Latitude")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(expected_lon_list, predicted_lon_list, c='red', label='Predicted LON')
plt.plot([min(expected_lon_list), max(expected_lon_list)], [min(expected_lon_list), max(expected_lon_list)], color='blue', linestyle='--', linewidth=2, label='Ideal Fit')
plt.title("Expected Longitude vs Predicted Longitude")
plt.xlabel("Expected Longitude")
plt.ylabel("Predicted Longitude")
plt.legend()
plt.grid()
plt.show()
# Out:
# Testing on dataset 1/99
# Testing on dataset 2/99
# Testing on dataset 3/99
# Testing on dataset 4/99
# Testing on dataset 5/99
# Testing on dataset 6/99
# Testing on dataset 7/99
# Testing on dataset 8/99
# Testing on dataset 9/99
# Testing on dataset 10/99
# Testing on dataset 11/99
# Testing on dataset 12/99
# Testing on dataset 13/99
# Testing on dataset 14/99
# Testing on dataset 15/99
# Testing on dataset 16/99
# Testing on dataset 17/99
# Testing on dataset 18/99
# Testing on dataset 19/99
# Testing on dataset 20/99
# Testing on dataset 21/99
# Testing on dataset 22/99
# Testing on dataset 23/99
# Testing on dataset 24/99
# Testing on dataset 25/99
# Testing on dataset 26/99
# Testing on dataset 27/99
# Testing on dataset 28/99
# Testing on dataset 29/99
# Testing on dataset 30/99
# Testing on dataset 31/99
# Testing on dataset 32/99
# Testing on dataset 33/99
# Testing on dataset 34/99
# Testing on dataset 35/99
# Testing on dataset 36/99
# Testing on dataset 37/99
# Testing on dataset 38/99
# Testing on dataset 39/99
# Testing on dataset 40/99
# Testing on dataset 41/99
# Testing on dataset 42/99
# Testing on dataset 43/99
# Testing on dataset 44/99
# Testing on dataset 45/99
# Testing on dataset 46/99
# Testing on dataset 47/99
# Testing on dataset 48/99
# Testing on dataset 49/99
# Testing on dataset 50/99
# Testing on dataset 51/99
# Testing on dataset 52/99
# Testing on dataset 53/99
# Testing on dataset 54/99
# Testing on dataset 55/99
# Testing on dataset 56/99
# Testing on dataset 57/99
# Testing on dataset 58/99
# Testing on dataset 59/99
# Testing on dataset 60/99
# Testing on dataset 61/99
# Testing on dataset 62/99
# Testing on dataset 63/99
# Testing on dataset 64/99
# Testing on dataset 65/99
# Testing on dataset 66/99
# Testing on dataset 67/99
# Testing on dataset 68/99
# Testing on dataset 69/99
# Testing on dataset 70/99
# Testing on dataset 71/99
# Testing on dataset 72/99
# Testing on dataset 73/99
# Testing on dataset 74/99
# Testing on dataset 75/99
# Testing on dataset 76/99
# Testing on dataset 77/99
# Testing on dataset 78/99
# Testing on dataset 79/99
# Testing on dataset 80/99
# Testing on dataset 81/99
# Testing on dataset 82/99
# Testing on dataset 83/99
# Testing on dataset 84/99
# Testing on dataset 85/99
# Testing on dataset 86/99
# Testing on dataset 87/99
# Testing on dataset 88/99
# Testing on dataset 89/99
# Testing on dataset 90/99
# Testing on dataset 91/99
# Testing on dataset 92/99
# Testing on dataset 93/99
# Testing on dataset 94/99
# Testing on dataset 95/99
# Testing on dataset 96/99
# Testing on dataset 97/99
# Testing on dataset 98/99
# Testing on dataset 99/99

# %%
#plot expected latitutde/longitude vs actual latitude/longitude
plt.figure(figsize=(10, 5))
plt.scatter(expected_lat_list, predicted_lat_list, c='blue', label='Predicted LAT')
plt.plot([min(expected_lat_list), max(expected_lat_list)], [min(expected_lat_list), max(expected_lat_list)], color='red', linestyle='--', linewidth=2, label='Ideal Fit')
plt.title("Expected Latitude vs Predicted Latitude")
plt.xlabel("Expected Latitude")
plt.ylabel("Predicted Latitude")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(expected_lon_list, predicted_lon_list, c='red', label='Predicted LON')
plt.plot([min(expected_lon_list), max(expected_lon_list)], [min(expected_lon_list), max(expected_lon_list)], color='blue', linestyle='--', linewidth=2, label='Ideal Fit')
plt.title("Expected Longitude vs Predicted Longitude")
plt.xlabel("Expected Longitude")
plt.ylabel("Predicted Longitude")
plt.legend()
plt.grid()
plt.show()

# %%
# Save the latitude model
torch.save(model_lat.state_dict(), "/cis/home/ywen15/Documents/Tornados/model_lat.pth") # /cis/home/ywen15/Documents/Tornados/DL_of_ML_Final_Stuff.ipynb

# Save the longitude model
torch.save(model_lon.state_dict(), "/cis/home/ywen15/Documents/Tornados/model_lon.pth")

print("Models saved to local device.")
# Out:
# Models saved to local device.
